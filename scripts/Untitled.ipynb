# %%
from pandas import DataFrame
from jmetal.util.visualization import CDplot
import pandas as pd
import xlrd
import matplotlib.pyplot as plt
import random
from scipy.stats import wilcoxon

# %%
loc = "/mnt/f/Datasets/CleanedDatasets2/Results_Other.xlsx"
wb = xlrd.open_workbook(loc)
sheet = wb.sheet_by_index(0)

# %%
headers = [sheet.cell_value(0, x).split(" ", 1)[1] for x in range(1, 16, 2)]
headers.append("Learning Based")
headers
# Out:
# ['Eskin',
#  'Gambaryan',
#  'Goodall',
#  'Lin',
#  'Occurence Frequency',
#  'Inverse Occurence Frequency',
#  'Euclidian',
#  'Manhattan',
#  'Learning Based']

# %%
data = [[sheet.cell_value(y, x) for y in range(1,30)] for x in range(2, 17, 2)]
data.append([0.95669949054718,
0.488440066576004,
0.60557234287262,
0.926907598972321,
0.935388684272766,
0.945910573005676,
0.906946301460266,
0.753199994564056,
0.567036509513855,
0.643799483776093,
0.338430732488632,
0.442556321620941,
0.428731143474579,
0.51003235578537,
0.299550831317902,
0.404154181480408,
0.442982524633408,
0.572174966335297,
0.491918951272964,
0.576572299003601,
0.562632977962494,
0.599180996417999,
0.508695304393768,
0.588397443294525,
0.483916461467743,
0.284301429986954,
0.598508477210999,
0.565373778343201,
0.688572227954865,

])
df = pd.DataFrame(data, index=headers)

df
# Out:
#                                    0         1         2         3         4   \
# Eskin                        0.792902  0.433592  0.512957  0.925732  0.929870
# Gambaryan                    0.838084  0.488440  0.601749  0.936098  0.948797
# Goodall                      0.593531  0.406724  0.674492  0.692900  0.700328
# Lin                          0.509735  0.409312  0.512957  0.815893  0.821100
# Occurence Frequency          0.593531  0.420018  0.674492  0.899737  0.908328
# Inverse Occurence Frequency  0.509735  0.430053  0.512957  0.870479  0.873152
# Euclidian                    0.593531  0.427456  0.674492  0.815893  0.821100
# Manhattan                    0.689215  0.433592  0.601749  0.925732  0.929870
# Learning Based               0.956699  0.488440  0.605572  0.926908  0.935389
#
#                                    5         6         7         8         9   \
# Eskin                        0.944737  0.907892  0.727323  0.564785  0.744626
# Gambaryan                    0.959229  0.914341  0.574890  0.734113  0.543498
# Goodall                      0.702558  0.683066  0.674584  0.542579  0.623955
# Lin                          0.833117  0.914341  0.674492  0.542579  0.560440
# Occurence Frequency          0.916687  0.883892  0.607120  0.564090  0.752475
# Inverse Occurence Frequency  0.889620  0.860484  0.565139  0.509957  0.725275
# Euclidian                    0.833117  0.803374  0.565139  0.632502  0.560440
# Manhattan                    0.944737  0.907892  0.646085  0.564785  0.744626
# Learning Based               0.945911  0.906946  0.753200  0.567037  0.643799
#
#                                ...           19        20        21        22  \
# Eskin                          ...     0.285494  0.278817  0.295217  0.276331
# Gambaryan                      ...     0.337921  0.336312  0.371852  0.335607
# Goodall                        ...     0.281095  0.275141  0.276255  0.268285
# Lin                            ...     0.275829  0.272868  0.284953  0.277471
# Occurence Frequency            ...     0.330426  0.324214  0.305031  0.281290
# Inverse Occurence Frequency    ...     0.346342  0.335830  0.378103  0.368277
# Euclidian                      ...     0.311081  0.298242  0.309027  0.285457
# Manhattan                      ...     0.313322  0.301284  0.294505  0.271777
# Learning Based                 ...     0.576572  0.562633  0.599181  0.508695
#
#                                    23        24        25        26        27  \
# Eskin                        0.287459  0.269005  0.203482  0.398933  0.279148
# Gambaryan                    0.344157  0.327837  0.227831  0.371233  0.330495
# Goodall                      0.274253  0.265182  0.203160  0.356061  0.271087
# Lin                          0.265965  0.263383  0.194176  0.363453  0.266746
# Occurence Frequency          0.311096  0.282927  0.232254  0.435242  0.317543
# Inverse Occurence Frequency  0.362247  0.351287  0.219041  0.386555  0.340605
# Euclidian                    0.311612  0.279873  0.208572  0.424387  0.306847
# Manhattan                    0.298958  0.273271  0.234619  0.410304  0.302372
# Learning Based               0.588397  0.483916  0.284301  0.598508  0.565374
#
#                                    28
# Eskin                        0.563615
# Gambaryan                    0.592502
# Goodall                      0.529939
# Lin                          0.511838
# Occurence Frequency          0.551849
# Inverse Occurence Frequency  0.527278
# Euclidian                    0.563615
# Manhattan                    0.563615
# Learning Based               0.688572
#
# [9 rows x 29 columns]

# %%
CDplot(df, higherIsBetter=True, alpha=0.05)

# %%
plt.isinteractive()
# Out:
# True

# %%
means = df.mean(axis=1)
means
# Out:
# Eskin                          0.444320
# Gambaryan                      0.474782
# Goodall                        0.396875
# Lin                            0.404594
# Occurence Frequency            0.451452
# Inverse Occurence Frequency    0.450423
# Euclidian                      0.427404
# Manhattan                      0.449898
# Learning Based                 0.590227
# dtype: float64

# %%
all_colors = list(plt.cm.colors.cnames.keys())
random.seed(100)
c = random.choices(all_colors, k=8)

# Plot Bars
plt.figure(figsize=(16,10), dpi= 80)
plt.bar(means.index, means, color=c, width=.5)
for i, val in enumerate(means.values):
    plt.text(i, val, "{0:.5f}".format(val), horizontalalignment='center', verticalalignment='bottom', fontdict={'fontweight':500, 'size':12})

# Decoration
plt.gca().set_xticklabels(df.index, rotation=60, horizontalalignment= 'right')
plt.title("Mean F1-Score in trained datasets", fontsize=22)
plt.ylabel('F1-Score')
#plt.ylim(0, 0.7)
plt.savefig("bars.png", transparent=True, bbox_inches="tight")
plt.show()

# %%
ls = df.index.values.tolist()

pairs = []
for i in df.index:
    idx = ls.index(i) + 1
    for j in ls[idx:]:
        pairs.append((i,j))

a = pd.DataFrame(index=df.index, columns=df.index)
        
for x, y in pairs:
    _, p = wilcoxon(df.loc[x], df.loc[y])
    if p < 0.01:
        ma = means[x]
        mb = means[y]
        best = x  if ma > mb else y
        print(f"{x} and {y} are statistically different and the better is {best}")
        a[y][x] = best
    else:
        print(f"{x} and {y} are not different")
        a[y][x] = "None"
# Out:
# Eskin and Gambaryan are statistically different and the better is Gambaryan
# Eskin and Goodall are statistically different and the better is Eskin
# Eskin and Lin are statistically different and the better is Eskin
# Eskin and Occurence Frequency are not different
# Eskin and Inverse Occurence Frequency are not different
# Eskin and Euclidian are not different
# Eskin and Manhattan are not different
# Eskin and Learning Based are statistically different and the better is Learning Based
# Gambaryan and Goodall are statistically different and the better is Gambaryan
# Gambaryan and Lin are statistically different and the better is Gambaryan
# Gambaryan and Occurence Frequency are not different
# Gambaryan and Inverse Occurence Frequency are not different
# Gambaryan and Euclidian are statistically different and the better is Gambaryan
# Gambaryan and Manhattan are statistically different and the better is Gambaryan
# Gambaryan and Learning Based are statistically different and the better is Learning Based
# Goodall and Lin are not different
# Goodall and Occurence Frequency are statistically different and the better is Occurence Frequency
# Goodall and Inverse Occurence Frequency are statistically different and the better is Inverse Occurence Frequency
# Goodall and Euclidian are statistically different and the better is Euclidian
# Goodall and Manhattan are statistically different and the better is Manhattan
# Goodall and Learning Based are statistically different and the better is Learning Based
# Lin and Occurence Frequency are statistically different and the better is Occurence Frequency
# Lin and Inverse Occurence Frequency are statistically different and the better is Inverse Occurence Frequency
# Lin and Euclidian are statistically different and the better is Euclidian
# Lin and Manhattan are statistically different and the better is Manhattan
# Lin and Learning Based are statistically different and the better is Learning Based
# Occurence Frequency and Inverse Occurence Frequency are not different
# Occurence Frequency and Euclidian are statistically different and the better is Occurence Frequency
# Occurence Frequency and Manhattan are not different
# Occurence Frequency and Learning Based are statistically different and the better is Learning Based
# Inverse Occurence Frequency and Euclidian are not different
# Inverse Occurence Frequency and Manhattan are not different
# Inverse Occurence Frequency and Learning Based are statistically different and the better is Learning Based
# Euclidian and Manhattan are not different
# Euclidian and Learning Based are statistically different and the better is Learning Based
# Manhattan and Learning Based are statistically different and the better is Learning Based

# %%
a
# Out:
#                             Eskin  Gambaryan    Goodall        Lin  \
# Eskin                         NaN  Gambaryan      Eskin      Eskin
# Gambaryan                     NaN        NaN  Gambaryan  Gambaryan
# Goodall                       NaN        NaN        NaN       None
# Lin                           NaN        NaN        NaN        NaN
# Occurence Frequency           NaN        NaN        NaN        NaN
# Inverse Occurence Frequency   NaN        NaN        NaN        NaN
# Euclidian                     NaN        NaN        NaN        NaN
# Manhattan                     NaN        NaN        NaN        NaN
# Learning Based                NaN        NaN        NaN        NaN
#
#                              Occurence Frequency  Inverse Occurence Frequency  \
# Eskin                                       None                         None
# Gambaryan                                   None                         None
# Goodall                      Occurence Frequency  Inverse Occurence Frequency
# Lin                          Occurence Frequency  Inverse Occurence Frequency
# Occurence Frequency                          NaN                         None
# Inverse Occurence Frequency                  NaN                          NaN
# Euclidian                                    NaN                          NaN
# Manhattan                                    NaN                          NaN
# Learning Based                               NaN                          NaN
#
#                                        Euclidian  Manhattan  Learning Based
# Eskin                                       None       None  Learning Based
# Gambaryan                              Gambaryan  Gambaryan  Learning Based
# Goodall                                Euclidian  Manhattan  Learning Based
# Lin                                    Euclidian  Manhattan  Learning Based
# Occurence Frequency          Occurence Frequency       None  Learning Based
# Inverse Occurence Frequency                 None       None  Learning Based
# Euclidian                                    NaN       None  Learning Based
# Manhattan                                    NaN        NaN  Learning Based
# Learning Based                               NaN        NaN             NaN
